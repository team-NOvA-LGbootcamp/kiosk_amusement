# %% [markdown]
# # CNN_SignMNIST

# %% [markdown]
# >### Load modules

# %%
import cv2
import os
import re
import glob
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import tensorflow as tf
import itertools
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input, Conv2D, MaxPooling2D, Flatten, Dense, Concatenate
from tensorflow.keras.utils import to_categorical
from collections import defaultdict

print("NumPy Version :{}".format(np.__version__))
print("TensorFlow Version :{}".format(tf.__version__))
print("Matplotlib Version :{}".format(plt.matplotlib.__version__))
# Out:
# NumPy Version :1.25.2
# TensorFlow Version :2.15.0
# Matplotlib Version :3.7.1

# %% [markdown]
# > ### Load Data

# %%
from google.colab import drive
drive.mount('/content/drive')
print('g-drive mounted.')
# Out:
# Mounted at /content/drive
# g-drive mounted.

# %%
files_path = '/content/PISC_relatoin_age_gender/'
if(os.path.isdir('/content/PISC_relatoin_age_gender/') == False):
  # !unzip -q '/content/drive/MyDrive/files/PISC_relatoin_age_gender.zip'

# %%
# %%time
IMG_SIZE = 224

dataset = defaultdict(lambda: defaultdict(dict))
filename_pattern = re.compile(r'image(\d+)_id(\d+)_([a-zA-Z]+)_(\w+)_(\w+).jpg')

for filename in tqdm(os.listdir(files_path), desc="Processing images", unit="image"):
    try:
        # Read and preprocess image
        img = cv2.imread(files_path+filename, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))

        match = filename_pattern.match(filename)
        if match:
            image_id, person_id, relationship, age, gender = match.groups()
            dataset[image_id][person_id] = {'image':img,'relationship': relationship, 'age': age, 'gender': gender}

    except Exception as e:
        print(f"Error processing {filename}: {e}")

input_data = []
output_data = []
relationship_table = {"friends":0,"family":1,"couple":2}
age_table = {"Infant":0,"Child":1,"YoungAdult":2,"MiddleAge":3,"Senior":4}

gender_table = {"male":0,"female":1}

for image_id, persons in dataset.items():
    person_ids = list(persons.keys())
    for person1_id, person2_id in itertools.combinations(person_ids, 2):
        person1 = persons[person1_id]
        person2 = persons[person2_id]

        age1 = age_table[person1['age']]
        age2 = age_table[person2['age']]
        gender1 = gender_table[person1['gender']]
        gender2 = gender_table[person2['gender']]
        relationship = relationship_table[person1['relationship']]

        input_data.append([
            person1['image'], age1, gender1,
            person2['image'], age2, gender2
        ])
        input_data.append([
            person2['image'], age2, gender2,
            person1['image'], age1, gender1
        ])
        output_data.append(relationship)
        output_data.append(relationship)


input_data = np.array(input_data, dtype=object)
output_data = to_categorical(output_data, num_classes=3)
print(len(input_data))
# Shuffle and split data
train_data, test_data, train_labels, test_labels = train_test_split(input_data, output_data, test_size=0.2, random_state=0)

def prepare_data(data):
    images1 = np.stack(data[:, 0])
    ages_genders1 = data[:, 1:3].astype('float32')
    images2 = np.stack(data[:, 3])
    ages_genders2 = data[:, 4:6].astype('float32')
    metadata = np.hstack((ages_genders1, ages_genders2))
    return [images1, images2, metadata]

train_data_prepared = prepare_data(train_data)
test_data_prepared = prepare_data(test_data)
# Out:
# Processing images: 100%|██████████| 716/716 [00:00<00:00, 986.21image/s]
# 824
# CPU times: user 652 ms, sys: 133 ms, total: 785 ms
# Wall time: 843 ms

# %%
image_input1 = Input(shape=(224, 224, 3))
image_input2 = Input(shape=(224, 224, 3))
metadata_input = Input(shape=(4,))

# CNN for image 1
x1 = Conv2D(16, (3, 3), activation='relu')(image_input1)
x1 = Dropout(0.2)(x1)
x1 = MaxPooling2D((4, 4))(x1)
x1 = Conv2D(16, (3, 3), activation='relu')(x1)
x1 = Dropout(0.2)(x1)
x1 = MaxPooling2D((4, 4))(x1)
x1 = Flatten()(x1)
x1 = Dense(4, activation='relu')(x1)


# CNN for image 2
x2 = Conv2D(16, (3, 3), activation='relu')(image_input2)
x2 = Dropout(0.2)(x2)
x2 = MaxPooling2D((4, 4))(x2)
x2 = Conv2D(16, (3, 3), activation='relu')(x2)
x2 = Dropout(0.2)(x2)
x2 = MaxPooling2D((4, 4))(x2)
x2 = Flatten()(x2)
x2 = Dense(4, activation='relu')(x2)

# Concatenate image features and metadata
concatenated = Concatenate()([x1, x2, metadata_input])
dense = Dense(256, activation='relu')(concatenated)
output = Dense(3, activation='softmax')(dense)

model = Model(inputs=[image_input1, image_input2, metadata_input], outputs=output)
model.summary()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 222, 222, 16)         448       ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 222, 222, 16)         448       ['input_2[0][0]']
#
#  dropout (Dropout)           (None, 222, 222, 16)         0         ['conv2d[0][0]']
#
#  dropout_2 (Dropout)         (None, 222, 222, 16)         0         ['conv2d_2[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 55, 55, 16)           0         ['dropout[0][0]']
#  D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 55, 55, 16)           0         ['dropout_2[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 53, 53, 16)           2320      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 53, 53, 16)           2320      ['max_pooling2d_2[0][0]']
#
#  dropout_1 (Dropout)         (None, 53, 53, 16)           0         ['conv2d_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 53, 53, 16)           0         ['conv2d_3[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 13, 13, 16)           0         ['dropout_1[0][0]']
#  g2D)
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 16)           0         ['dropout_3[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 2704)                 0         ['max_pooling2d_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 2704)                 0         ['max_pooling2d_3[0][0]']
#
#  dense (Dense)               (None, 4)                    10820     ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 4)                    10820     ['flatten_1[0][0]']
#
#  input_3 (InputLayer)        [(None, 4)]                  0         []
#
#  concatenate (Concatenate)   (None, 12)                   0         ['dense[0][0]',
#                                                                      'dense_1[0][0]',
#                                                                      'input_3[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  3328      ['concatenate[0][0]']
#
#  dense_3 (Dense)             (None, 3)                    771       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 31275 (122.17 KB)
# Trainable params: 31275 (122.17 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
savedModelName = 'relationship_prediction_model_v2.h5'
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(savedModelName,
                                    save_best_only=True)
]

# %%
model.fit(train_data_prepared, train_labels, epochs=50, batch_size=32,
          validation_data=(test_data_prepared, test_labels))
# Out:
# Epoch 1/50
# 21/21 [==============================] - 10s 94ms/step - loss: 2.0459 - accuracy: 0.4143 - val_loss: 1.0774 - val_accuracy: 0.3697
# Epoch 2/50
# 21/21 [==============================] - 1s 49ms/step - loss: 1.0414 - accuracy: 0.5008 - val_loss: 0.9846 - val_accuracy: 0.5576
# Epoch 3/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.9948 - accuracy: 0.6070 - val_loss: 0.9435 - val_accuracy: 0.6545
# Epoch 4/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.9570 - accuracy: 0.5812 - val_loss: 0.9114 - val_accuracy: 0.6667
# Epoch 5/50
# 21/21 [==============================] - 1s 49ms/step - loss: 0.9255 - accuracy: 0.5933 - val_loss: 0.8774 - val_accuracy: 0.6727
# Epoch 6/50
# 21/21 [==============================] - 1s 54ms/step - loss: 0.8923 - accuracy: 0.5933 - val_loss: 0.8425 - val_accuracy: 0.6667
# Epoch 7/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.8645 - accuracy: 0.5979 - val_loss: 0.8188 - val_accuracy: 0.6727
# Epoch 8/50
# 21/21 [==============================] - 1s 47ms/step - loss: 0.8364 - accuracy: 0.6009 - val_loss: 0.7898 - val_accuracy: 0.6727
# Epoch 9/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.8137 - accuracy: 0.6404 - val_loss: 0.7681 - val_accuracy: 0.7394
# Epoch 10/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.7917 - accuracy: 0.6601 - val_loss: 0.7504 - val_accuracy: 0.7576
# Epoch 11/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.7725 - accuracy: 0.6722 - val_loss: 0.7319 - val_accuracy: 0.7576
# Epoch 12/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.7549 - accuracy: 0.6737 - val_loss: 0.7158 - val_accuracy: 0.7576
# Epoch 13/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.7405 - accuracy: 0.6601 - val_loss: 0.7034 - val_accuracy: 0.7576
# Epoch 14/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.7258 - accuracy: 0.6874 - val_loss: 0.6907 - val_accuracy: 0.7576
# Epoch 15/50
# 21/21 [==============================] - 1s 49ms/step - loss: 0.7087 - accuracy: 0.6813 - val_loss: 0.6741 - val_accuracy: 0.7576
# Epoch 16/50
# 21/21 [==============================] - 1s 58ms/step - loss: 0.6955 - accuracy: 0.7086 - val_loss: 0.6686 - val_accuracy: 0.7636
# Epoch 17/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6845 - accuracy: 0.6859 - val_loss: 0.6591 - val_accuracy: 0.7576
# Epoch 18/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6735 - accuracy: 0.7329 - val_loss: 0.6557 - val_accuracy: 0.7273
# Epoch 19/50
# 21/21 [==============================] - 1s 49ms/step - loss: 0.6633 - accuracy: 0.7542 - val_loss: 0.6474 - val_accuracy: 0.7273
# Epoch 20/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.6561 - accuracy: 0.7466 - val_loss: 0.6447 - val_accuracy: 0.7273
# Epoch 21/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.6501 - accuracy: 0.7557 - val_loss: 0.6347 - val_accuracy: 0.7273
# Epoch 22/50
# 21/21 [==============================] - 1s 47ms/step - loss: 0.6404 - accuracy: 0.7496 - val_loss: 0.6315 - val_accuracy: 0.7212
# Epoch 23/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6321 - accuracy: 0.7602 - val_loss: 0.6265 - val_accuracy: 0.7273
# Epoch 24/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6246 - accuracy: 0.7496 - val_loss: 0.6190 - val_accuracy: 0.7273
# Epoch 25/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6203 - accuracy: 0.7542 - val_loss: 0.6154 - val_accuracy: 0.7273
# Epoch 26/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6149 - accuracy: 0.7557 - val_loss: 0.6190 - val_accuracy: 0.7273
# Epoch 27/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6104 - accuracy: 0.7542 - val_loss: 0.6095 - val_accuracy: 0.7212
# Epoch 28/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6071 - accuracy: 0.7587 - val_loss: 0.6130 - val_accuracy: 0.7273
# Epoch 29/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6002 - accuracy: 0.7542 - val_loss: 0.6095 - val_accuracy: 0.7273
# Epoch 30/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5974 - accuracy: 0.7587 - val_loss: 0.6022 - val_accuracy: 0.7212
# Epoch 31/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5922 - accuracy: 0.7648 - val_loss: 0.6073 - val_accuracy: 0.7091
# Epoch 32/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5887 - accuracy: 0.7602 - val_loss: 0.6033 - val_accuracy: 0.7273
# Epoch 33/50
# 21/21 [==============================] - 1s 52ms/step - loss: 0.5862 - accuracy: 0.7648 - val_loss: 0.5982 - val_accuracy: 0.7091
# Epoch 34/50
# 21/21 [==============================] - 1s 49ms/step - loss: 0.5826 - accuracy: 0.7618 - val_loss: 0.6045 - val_accuracy: 0.7152
# Epoch 35/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.5801 - accuracy: 0.7754 - val_loss: 0.5963 - val_accuracy: 0.7091
# Epoch 36/50
# 21/21 [==============================] - 1s 54ms/step - loss: 0.5783 - accuracy: 0.7724 - val_loss: 0.5940 - val_accuracy: 0.7152
# Epoch 37/50
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5775 - accuracy: 0.7724 - val_loss: 0.5942 - val_accuracy: 0.7091
# Epoch 38/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5762 - accuracy: 0.7800 - val_loss: 0.5982 - val_accuracy: 0.7152
# Epoch 39/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.5747 - accuracy: 0.7709 - val_loss: 0.5887 - val_accuracy: 0.7091
# Epoch 40/50
# 21/21 [==============================] - 1s 45ms/step - loss: 0.5733 - accuracy: 0.7785 - val_loss: 0.5961 - val_accuracy: 0.7091
# Epoch 41/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.5727 - accuracy: 0.7769 - val_loss: 0.6021 - val_accuracy: 0.7152
# Epoch 42/50
# 21/21 [==============================] - 1s 44ms/step - loss: 0.5684 - accuracy: 0.7724 - val_loss: 0.5893 - val_accuracy: 0.7152
# Epoch 43/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.5674 - accuracy: 0.7754 - val_loss: 0.5947 - val_accuracy: 0.7212
# Epoch 44/50
# 21/21 [==============================] - 1s 55ms/step - loss: 0.5659 - accuracy: 0.7739 - val_loss: 0.5902 - val_accuracy: 0.7091
# Epoch 45/50
# 21/21 [==============================] - 1s 61ms/step - loss: 0.5636 - accuracy: 0.7739 - val_loss: 0.5998 - val_accuracy: 0.7212
# Epoch 46/50
# 21/21 [==============================] - 2s 76ms/step - loss: 0.5632 - accuracy: 0.7769 - val_loss: 0.5887 - val_accuracy: 0.7091
# Epoch 47/50
# 21/21 [==============================] - 1s 69ms/step - loss: 0.5597 - accuracy: 0.7769 - val_loss: 0.5946 - val_accuracy: 0.7212
# Epoch 48/50
# 21/21 [==============================] - 1s 53ms/step - loss: 0.5602 - accuracy: 0.7754 - val_loss: 0.5832 - val_accuracy: 0.7091
# Epoch 49/50
# 21/21 [==============================] - 1s 52ms/step - loss: 0.5577 - accuracy: 0.7785 - val_loss: 0.5967 - val_accuracy: 0.7212
# Epoch 50/50
# 21/21 [==============================] - 1s 46ms/step - loss: 0.5561 - accuracy: 0.7815 - val_loss: 0.5913 - val_accuracy: 0.7152

# %%
model.save("/content/drive/MyDrive/files/save/"+savedModelName)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
save_dir = '/content/drive/MyDrive/files/save/'
model_best = tf.keras.models.load_model("/content/drive/MyDrive/files/save/"+savedModelName)
converter = tf.lite.TFLiteConverter.from_keras_model(model_best)
tflite_model = converter.convert()
tfliteFileName = 'relationship_prediction_model_v2.tflite'
open(save_dir + tfliteFileName, 'ab').write(tflite_model)
# Out:
# 131076

# %%
pred = model.predict(test_data_prepared)

id = 2
for id in range(len(pred)):
  rel = ["friend","family",'couple']
  # print(rel[np.argmax(pred[id])])
  # print(rel[np.argmax(test_labels[id])])
  # if np.argmax(pred[id]) != np.argmax(test_labels[id]):

  if np.argmax(pred[id]) == 2:
    # print(pred[id])
    print("pred:",rel[np.argmax(pred[id])])
    print("lable:",rel[np.argmax(test_labels[id])])
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(test_data_prepared[0][id])
    plt.title('Person 1')

    plt.subplot(1, 2, 2)
    plt.imshow(test_data_prepared[1][id])
    plt.title('Person 2')

    plt.show()
